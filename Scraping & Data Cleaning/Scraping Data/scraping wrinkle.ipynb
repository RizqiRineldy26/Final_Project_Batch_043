# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd 
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv("Skincare Dataset/wrinkle.csv")
df = df.loc[:, ~df.columns.str.contains("^Unnamed: 0")]

df.head(10)
# Out:
#     problem ingredient                                       product name  \
# 0  wrinkles  tretinoin                               A-Ret Tretinoin 0.1%
# 1  wrinkles  tretinoin                          A-Ret Tretinoin Gel 0.05%
# 2  wrinkles  tretinoin                              ASSOS Tre® %0.05 Krem
# 3  wrinkles  tretinoin                               Abdiibrahim Acnelyse
# 4  wrinkles  tretinoin                          Acnelyse Tretinoin %0.025
# 5  wrinkles  tretinoin                           Acnelyse Tretinoin %0.05
# 6  wrinkles  tretinoin                      Acretin 0.05% Tretinoin Cream
# 7  wrinkles  tretinoin                     Acretin Tretinoin 0.025% Cream
# 8  wrinkles  tretinoin  Actavis Pharma, Inc. Actavis Tretinoin Cream, ...
# 9  wrinkles  tretinoin                        Airol cream 0.5 Airol Cream
#
#                                         product link
# 0  https://inkeedecoder.com/products/a-ret-tretin...
# ...

# %% [markdown]
# ##### Membuat Driver untuk Chrome Browser

# %%
driver = webdriver.Chrome()

# %% [markdown]
# ##### Scraping Data

# %%
for index, row in df.iterrows():
    url = row["product link"]

    driver.get(url)
    time.sleep(2)

    soup = BeautifulSoup(driver.page_source, "html.parser")

    ingredient_elements = soup.select("a.ingred-link")

    ingredients = []

    for ing in ingredient_elements:
        ingredient_name = ing.get_text(strip=True)

        if ingredient_name not in ingredients:
            ingredients.append(ingredient_name)

    if len(ingredients) > 0:
        df.loc[index, "ingredient"] = ", ".join(ingredients)

    print("Product:", row["product name"])
    print("Link:", url)
    print("Jumlah ingredient:", len(ingredients))
    print("Ingredient:", ingredients)
    print("-" * 50)
    
driver.quit()
# Out:
# Product: A-Ret Tretinoin 0.1%
# Link: https://inkeedecoder.com/products/a-ret-tretinoin-0-1
# Jumlah ingredient: 8
# Ingredient: ['Tretinoin', 'Propylene Glycol', 'Isopropanol', 'Carbomer', 'Triethanolamine', 'Butylated Hydroxytoluene', 'Methyl Hydroxybenzoate', 'Propyl Hydroxybenzoate']
# --------------------------------------------------
# Product: A-Ret Tretinoin Gel 0.05%
# Link: https://inkeedecoder.com/products/a-ret-tretinoin-gel-0-05
# Jumlah ingredient: 11
# Ingredient: ['Tretinoin', 'PEG-4 Olivate', 'Olive Oil PEG-7 Esters', 'Methyl Hydroxybenzoate', 'Propyl Hydroxybenzoate', 'Propylene Glycol', 'Silicon Oil', 'Caprylic/\u200bCapric Triglyceride', 'Carbomer', 'Triethanolamine', 'Purified Water']
# --------------------------------------------------
# Product: ASSOS Tre® %0.05 Krem
# Link: https://inkeedecoder.com/products/assos-tre-r-0-05-krem
# Jumlah ingredient: 13
# ...

# %% [markdown]
# Hal tersebut dilakukan untuk menambahkan kolom `ingredient` yang sebelumnya hanya terdapat 1 untuk setiap kelompok produk.
#
# Oleh karena itu, scraping data dilakukan agar kolom ingredient per product lebih lengkap dan detail.
#
# Pada masalah kulit pori-pori besar atau pores. Setiap produk mempunyai jumlah yang ingredients yang bervariasi. Satu produk mempunyai sekitar 4 - 110 ingredients yang berbeda-beda.

# %%
df.to_csv("Skincare Dataset/wrinkle.csv", index=False)

df.head(10)
# Out:
#     problem                                         ingredient  \
# 0  wrinkles  Tretinoin, Propylene Glycol, Isopropanol, Carb...
# 1  wrinkles  Tretinoin, PEG-4 Olivate, Olive Oil PEG-7 Este...
# 2  wrinkles  Retinoic Acid Tretinoin (0.5), Isopropyl Myris...
# 3  wrinkles  Tretinoin, Cetyl Alcohol, Stearyl Alcohol, Twe...
# 4  wrinkles  Tretinoin (0.025), Butylhydroxytoluene (E321),...
# 5  wrinkles  Tretinoin (0,05%), Butylhydroxytoluene (E321),...
# 6  wrinkles  Tretinoin (0.05%), Polyoxyl 40 Stearate, Stear...
# 7  wrinkles  Tretinoin (0.025%), Stearyl Alcohol, Isopropyl...
# 8  wrinkles  Tretinoin (0.025%), Stearic Acid, Polyolprepol...
# 9  wrinkles  Tretinoin (0.5 Mg), Butylhydroxyanisole (E320)...
#
#                                         product name  \
# 0                               A-Ret Tretinoin 0.1%
# 1                          A-Ret Tretinoin Gel 0.05%
# 2                              ASSOS Tre® %0.05 Krem
# 3                               Abdiibrahim Acnelyse
# ...

# %% [markdown]
# Data yang sudah di scraping disimpan dan diperbarui ke dalam bentuk csv agar dapat di masukkan ke database supabase
#
# Terlihat dari 10 hasil awal yang di tampilkan setiap produk memiliki ingredient yang berbeda-beda.
